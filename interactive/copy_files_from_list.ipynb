# %%
import os
import shutil

# %%
to_path = "/mnt/hd2/images/web/"
from_path = "/mnt/hd-4tb/images/web-convert/"
image_list = os.path.expanduser("~/data/paths/all_images_shuf.txt")
dataset_size = 600000 # for saving IPCA files from 5% of data

# %%
filepaths = []

with open(image_list, "r") as f:
    lines = f.readlines()
    print("length:",len(lines))
    print(lines[0])
for l in lines:
    # substrings = l.rsplit(",", 1)
    filepaths.append(l.strip())
    # image_ids.append(substrings[1].strip())
    # resize to make sure we don't try and read more images than we have
# Out:
# length: 12694664
# 4111723.jpg

# %%
filepaths = filepaths[:dataset_size]
print(len(filepaths))
# Out:
# 600000

# %%
for i, f in enumerate(filepaths[:]):
    if i % 1000 == 0:
        print(f'i: {i}')
    source = os.path.join(from_path, f)
    target = os.path.join(to_path, f)
#     print(f'copying {source} to {target}')
    try:
        shutil.copy(source, target)
    except IOError as e:
        print(f'error with {source} - {target} : {e}')
    except:
        print(f'unexpected error with {source} - {target} : {sys.exc_info()}')
# Out:
# i: 0
# i: 1000
# i: 2000
# i: 3000
# i: 4000
# i: 5000
# i: 6000
# i: 7000
# i: 8000
# i: 9000
# i: 10000
# i: 11000
# i: 12000
# i: 13000
# i: 14000
# i: 15000
# i: 16000
# i: 17000
# i: 18000
# i: 19000
# i: 20000
# i: 21000
# i: 22000
# i: 23000
# i: 24000
# i: 25000
# i: 26000
# i: 27000
# i: 28000
# i: 29000
# i: 30000
# i: 31000
# i: 32000
# i: 33000
# i: 34000
# i: 35000
# i: 36000
# i: 37000
# i: 38000
# i: 39000
# i: 40000
# i: 41000
# i: 42000
# i: 43000
# i: 44000
# i: 45000
# i: 46000
# i: 47000
# i: 48000
# i: 49000
# i: 50000
# i: 51000
# i: 52000
# i: 53000
# i: 54000
# i: 55000
# i: 56000
# i: 57000
# i: 58000
# i: 59000
# i: 60000
# i: 61000
# i: 62000
# i: 63000
# i: 64000
# i: 65000
# i: 66000
# i: 67000
# i: 68000
# i: 69000
# i: 70000
# i: 71000
# i: 72000
# i: 73000
# i: 74000
# i: 75000
# i: 76000
# i: 77000
# i: 78000
# i: 79000
# i: 80000
# i: 81000
# i: 82000
# i: 83000
# i: 84000
# i: 85000
# i: 86000
# i: 87000
# i: 88000
# i: 89000
# i: 90000
# i: 91000
# ...
