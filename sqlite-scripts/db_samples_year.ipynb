# %% [markdown]
# # Sampling images from database
#
# This notebook provides Python code to access different combinations of images from the database and use them to create montages (tiled grids of images).

# %%
import sqlite3
import random
import itertools
import subprocess
import os
import shlex
import re

# %%
# path on rte
db_path = "/home/rte/data/db/arxiv_db_images.sqlite3"

# %%
# Here we import the sqlite3 database and create a cursor

db = sqlite3.connect(db_path)
c = db.cursor()

# %%
# test that we can fetch the pragma for each table

c.execute('PRAGMA TABLE_INFO({})'.format("metadata"))
info = c.fetchall()

print("\nColumn Info:\nID, Name, Type, NotNull, DefaultVal, PrimaryKey")
for col in info:
    print(col)
# Out:
# Column Info:
# ID, Name, Type, NotNull, DefaultVal, PrimaryKey
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'identifier', 'TEXT', 0, None, 0)
# (2, 'created', 'TEXT', 0, None, 0)
# (3, 'cat', 'TEXT', 0, None, 0)
# (4, 'authors', 'TEXT', 0, None, 0)
# (5, 'title', 'TEXT', 0, None, 0)
# (6, 'abstract', 'TEXT', 0, None, 0)
# (7, 'licence', 'TEXT', 0, None, 0)

# %%
c.execute('PRAGMA TABLE_INFO({})'.format("images"))
info = c.fetchall()

print("\nColumn Info:\nID, Name, Type, NotNull, DefaultVal, PrimaryKey")
for col in info:
    print(col)
# Out:
# Column Info:
# ID, Name, Type, NotNull, DefaultVal, PrimaryKey
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'identifier', 'TEXT', 0, None, 0)
# (2, 'filename', 'TEXT', 0, None, 0)
# (3, 'filesize', 'INT', 0, None, 0)
# (4, 'path', 'TEXT', 0, None, 0)
# (5, 'x', 'INT', 0, None, 0)
# (6, 'y', 'INT', 0, None, 0)
# (7, 'imageformat', 'TEXT', 0, None, 0)
# (8, 'creator', 'TEXT', 0, None, 0)

# %%
# Get total number of images per primary category only

targetDate = "2018-01-01"

c.execute('''
    SELECT substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1), count(images.identifier)
    FROM images
    LEFT JOIN metadata ON images.identifier = metadata.identifier
    WHERE metadata.created BETWEEN date(?) 
    AND date(?, "start of month","+12 month","-1 day")
    AND images.x != ''
    GROUP BY substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1)
    ORDER BY count(images.identifier) DESC    
    ''', (targetDate, targetDate,))
categories = c.fetchall()
for row in categories:
    print(row)
# Out:
# ('cs.CV', 188042)
# ('cs.LG', 78680)
# ('astro-ph.GA', 74039)
# ('hep-ph', 55548)
# ('astro-ph.SR', 45081)
# ('math.NA', 37881)
# ('astro-ph.HE', 34364)
# ('quant-ph', 34180)
# ('stat.ML', 33367)
# ('hep-th', 25609)
# ('astro-ph.CO', 24586)
# ('astro-ph.EP', 23525)
# ('cond-mat.mes-hall', 23393)
# ('cs.RO', 23304)
# ('physics.flu-dyn', 21927)
# ('cond-mat.str-el', 21553)
# ('math.OC', 21222)
# ('gr-qc', 21053)
# ('cs.CL', 19844)
# ('cs.IT', 19725)
# ('eess.SP', 18039)
# ('cond-mat.mtrl-sci', 17494)
# ('cs.CR', 17362)
# ('astro-ph.IM', 17216)
# ('cs.NI', 16822)
# ('stat.ME', 16047)
# ('hep-ex', 15880)
# ('cs.DC', 13721)
# ('cs.AI', 13540)
# ('cond-mat.stat-mech', 13532)
# ('nucl-th', 13388)
# ('cond-mat.soft', 13306)
# ('physics.ins-det', 13084)
# ('physics.comp-ph', 12532)
# ('cs.SI', 12247)
# ('cs.SY', 10670)
# ('math.GT', 8787)
# ('math.CO', 8637)
# ('stat.AP', 8635)
# ('eess.IV', 8486)
# ('cs.GR', 8025)
# ('physics.optics', 8002)
# ('physics.soc-ph', 8001)
# ('cond-mat.quant-gas', 7706)
# ('math.DS', 7417)
# ('cond-mat.supr-con', 7410)
# ('cs.SE', 7388)
# ('math.AP', 7314)
# ('hep-lat', 7062)
# ('cs.IR', 6678)
# ('cs.NE', 6567)
# ('cs.DS', 6497)
# ('cs.DB', 6418)
# ('math.ST', 6129)
# ('nucl-ex', 6119)
# ('physics.plasm-ph', 6066)
# ('math.PR', 5491)
# ('physics.app-ph', 5415)
# ('physics.chem-ph', 5247)
# ('math-ph', 5207)
# ('cs.CG', 5101)
# ('cs.HC', 5038)
# ('stat.CO', 4607)
# ('physics.atom-ph', 4582)
# ('cs.CY', 4570)
# ('cs.CE', 4312)
# ('cond-mat.dis-nn', 4009)
# ('physics.acc-ph', 3758)
# ('q-bio.NC', 3738)
# ('q-bio.PE', 3237)
# ('cs.SD', 3136)
# ('nlin.PS', 3050)
# ('physics.bio-ph', 3035)
# ('q-bio.QM', 2834)
# ('cs.ET', 2765)
# ('physics.med-ph', 2631)
# ('nlin.CD', 2627)
# ('cs.GT', 2531)
# ('math.DG', 2522)
# ('econ.EM', 2423)
# ('math.AG', 2423)
# ('cs.AR', 2348)
# ('cs.NA', 2255)
# ('cs.MM', 2243)
# ('physics.geo-ph', 2055)
# ('eess.AS', 2033)
# ('physics.data-an', 1922)
# ('math.CT', 1920)
# ('physics.class-ph', 1850)
# ('cs.PL', 1777)
# ('physics.ao-ph', 1776)
# ('cs.MA', 1672)
# ('cs.DM', 1592)
# ('cs.PF', 1541)
# ('cs.LO', 1503)
# ('cs.CC', 1394)
# ('physics.space-ph', 1349)
# ('math.SG', 1253)
# ('nlin.AO', 1252)
# ('cs.MS', 1250)
# ('physics.gen-ph', 1238)
# ('math.QA', 1214)
# ('q-fin.ST', 1186)
# ('math.CA', 1127)
# ('math.NT', 1111)
# ('nlin.SI', 1096)
# ('math.MG', 1076)
# ('q-fin.CP', 1033)
# ('q-bio.BM', 968)
# ('math.GR', 965)
# ('math.RT', 949)
# ('physics.ed-ph', 927)
# ('cs.DL', 891)
# ('math.HO', 880)
# ('q-fin.MF', 858)
# ('q-bio.MN', 854)
# ('q-fin.TR', 845)
# ('q-bio.CB', 844)
# ('math.AT', 819)
# ('cond-mat.other', 750)
# ('cs.OH', 742)
# ('q-bio.GN', 679)
# ('math.FA', 639)
# ('q-fin.RM', 604)
# ('nlin.CG', 588)
# ('econ.GN', 587)
# ('math.SP', 587)
# ('q-bio.TO', 574)
# ('math.CV', 569)
# ('cs.FL', 543)
# ('physics.hist-ph', 536)
# ('q-fin.PR', 509)
# ('cs.OS', 501)
# ('physics.atm-clus', 494)
# ('physics.pop-ph', 434)
# ('q-fin.PM', 396)
# ('math.GM', 389)
# ('q-bio.SC', 341)
# ('q-fin.GN', 284)
# ('stat.OT', 265)
# ('math.RA', 237)
# ('q-bio.OT', 234)
# ('math.OA', 231)
# ('econ.TH', 223)
# ('math.AC', 165)
# ('math.LO', 155)
# ('cs.SC', 145)
# ('math.GN', 81)
# ('q-fin.EC', 72)
# ('math.KT', 16)
# ('cs.GL', 15)

# %%
print(len(categories))

# %%
print(categories[0][0])

# %%
# remove entries with less than 144 total images

catlist = []

for cat in categories:
    if cat[1] >= 144:
        catlist.append(cat)
        print(cat)

print('-' * 20)
print("total number of categories with required entries: ")
print(len(catlist))

# %%
print(catlist[0][0])

# %%
# Get each image entry with a particular category in a given month

sql = ("SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created, images.id "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE metadata.created BETWEEN date('2018-10-01') "
    "AND date('2018-10-31') "
    "AND images.x != '' "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? ")

c.execute(sql, (catlist[0][0],))
rows = c.fetchall()

# %%
# Get each image entry with a particular category in a given month
# Specifically, get all images from cs.CV from 2012

sql = ("SELECT metadata.authors, metadata.title, metadata.created, metadata.identifier  "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE metadata.created BETWEEN date('2012-01-01') "
    "AND date('2012-12-31') "
    "AND images.x != '' "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? ")

c.execute(sql, ('cs.CV',))
rows = c.fetchall()

# %%
# Get each image entry with a particular category in a given month
# Specifically, get all images from stat.ML from 2012

sql = ("SELECT metadata.authors, metadata.title, metadata.created, metadata.identifier  "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE metadata.created BETWEEN date('2012-01-01') "
    "AND date('2012-12-31') "
    "AND images.x != '' "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? ")

c.execute(sql, ('stat.ML',))
rows = c.fetchall()

# %%
print(len(rows))

# %%
for row in rows[:100]:
    print(row)

# %%
without_duplicates = []
for row in rows[:]:
    if row not in without_duplicates:
        without_duplicates.append(row)

# %%
print(len(without_duplicates))
for row in without_duplicates[:]:
    print(row)

# %%
rows = without_duplicates

# %%
# TESTING ONLY

# Get each image entry with a particular category in a given month
# Specifically, get all images from cs.CV from 2012

sql = ("SELECT metadata.authors, metadata.title, metadata.created, metadata.identifier  "
    "FROM metadata "
    "WHERE metadata.created BETWEEN date('2012-01-01') "
    "AND date('2012-12-31') "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? ")

c.execute(sql, ('cs.CV',))
rows = c.fetchall()

# %%
print(len(rows))

# %%
for row in rows[:100]:
    print(row)

# %%
# convert to tuples
rows = [(x,) for x in rows[:]]

# %% [markdown]
# ### Get accreditations formatted

# %%
# go through all of the retrieved SQL rows and format as an accreditation
# if html is True, format with <a href=####> for web usage
# input = [[author, title, date, identifier], [author, title, date, identifier],...[author, title, date, identifier]]

def format_credits(rows, html=False):
    accreditations = []

    empty_counter = 0
    
    # html = True
#     html = False

    # grab the details and check each
    for i, row in enumerate(rows):
        print(i)
        if row:
            s = row[0]
            start = "['"
            end = "']"
            author = s[s.find(start)+len(start):s.rfind(end)]
            author = author[:-2]
            print(author)

            title = row[1]
            # replace line breaks and double spaces
            title = title.replace("\n", "").replace("  "," ")
            print(title)

            date = row[2].split("-")[0]
            print(date)

            identifier = row[3]
            print(identifier)
        #     reg_exp = re.compile("/[^\d]\d{2}[^\d]/")
            longest_digits = max(re.findall(r'\d+', identifier), key = len)
            print(len(longest_digits))

            # if the identifier contains seven consecutive numbers, add a slash
            if len(longest_digits) == 7:
                print("----- regex match -----")
                reverse = identifier[::-1]
                print(reverse)
                identifier_reverse = reverse[:7] + "/" + reverse[7:]
                identifier = identifier_reverse[::-1]
            else:
                # otherwise we can leave the identifier how it is
                print("----- no match -----")
            print(identifier)
            url = "https://arxiv.org/abs/" + identifier
            print(url)
            print("*" * 20)
        #     print(row[0])

            # format string and append
            if html:
                fmt_str = '{}: {}, {}, <a href="{}">{}</a>'
                accreditations.append(fmt_str.format(author, title, str(date), url, url))  
            else:
                fmt_str = '{}: {}, {}, {}'
                accreditations.append(fmt_str.format(author, title, str(date), url, url))
        else:
            empty_counter += 1
            print("empty!")

    print("number of empty slots:", empty_counter)
    return accreditations

# %%
# print out with line breaks
for row in accreditations:
    print(row)

# %% [markdown]
# ### Get random images

# %%
# Get 144 random images

sql = ("SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created, images.id "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE images.x != '' "
    "AND images.id IN (SELECT images.id FROM images ORDER BY RANDOM() LIMIT 144) ")

c.execute(sql, )
rows = c.fetchall()

# %%
# Get 144 images from stat.ML

# maybe move this???

sql = ("SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created, images.id "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE images.x != '' "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? "
    "AND images.id IN (SELECT images.id FROM images ORDER BY RANDOM() LIMIT 144) ")

c.execute(sql, ("stat.ML", ))
rows = c.fetchall()

# %%
# Get 144 images from stat.ML from October 2012

# maybe move this???

sql = ("SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created, images.id "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE images.x != '' "
    "AND metadata.created BETWEEN date('2012-10-01') "
    "AND date('2012-10-31') "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? "
    "AND images.id IN (SELECT images.id FROM images ORDER BY RANDOM() LIMIT 144) ")

c.execute(sql, ("stat.ML", ))
rows = c.fetchall()

# %%
# Get 16 random images

sql = ("SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created, images.id "
    "FROM images "
    "LEFT JOIN metadata ON images.identifier = metadata.identifier "
    "WHERE images.x != '' "
    "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? "
    "ORDER BY RANDOM() LIMIT 144 ")

c.execute(sql, ("stat.ML", ))
rows = c.fetchall()

# %%
print(len(rows))

# %%
for row in rows:
    print(row)

# %%
# check to see if there are multiple categories
for row in rows:
    if len(row[0]) > 5:
        print(row)

# %% [markdown]
# ### Shuffle list and then grab the filepath and id

# %%
# shuffle first, then get ids and paths

random.shuffle(rows)

# %%
ids = []
filepaths = []

for row in rows[:144]:
    print(row[5])
    ids.append(row[5])
    path = row[1] + '/' + row[2]
    print(path)
    filepaths.append(path)
# Out:
# 9059685
# ./1210/1210.8363/7lane_formation_start-eps-converted-to.pdf
# 9059696
# ./1210/1210.8363/6transient_block3-eps-converted-to.pdf
# 9059692
# ./1210/1210.8363/3merge-eps-converted-to.pdf
# 9059687
# ./1210/1210.8363/w11-eps-converted-to.pdf
# 9059690
# ./1210/1210.8363/jam-eps-converted-to.pdf
# 9059698
# ./1210/1210.8363/w13-eps-converted-to.pdf
# 9059689
# ./1210/1210.8363/BM_nstudyN=1-eps-converted-to.pdf
# 9059699
# ./1210/1210.8363/q-eps-converted-to.pdf
# 9059702
# ./1210/1210.8363/2encounter-eps-converted-to.pdf
# 9082443
# ./1210/1210.7562/fig2.eps
# 9059691
# ./1210/1210.8363/blockphase-eps-converted-to.pdf
# 9059686
# ./1210/1210.8363/simu07-eps-converted-to.pdf
# 9059697
# ./1210/1210.8363/simu10-eps-converted-to.pdf
# 9059700
# ./1210/1210.8363/clogging-eps-converted-to.pdf
# 9059693
# ./1210/1210.8363/8lane-eps-converted-to.pdf
# 9059684
# ./1210/1210.8363/4transient_block-eps-converted-to.pdf
# 9082441
# ./1210/1210.7562/fig1b.eps
# 9059694
# ./1210/1210.8363/1initial-eps-converted-to.pdf
# 9059688
# ./1210/1210.8363/w12-eps-converted-to.pdf
# 9059695
# ./1210/1210.8363/schematic-eps-converted-to.pdf
# 9059703
# ./1210/1210.8363/9normal-eps-converted-to.pdf
# 9059704
# ./1210/1210.8363/N-eps-converted-to.pdf
# 9082442
# ./1210/1210.7562/fig1a.eps
# 9059701
# ./1210/1210.8363/5transient_block2-eps-converted-to.pdf

# %%
print(filepaths)
# Out:
# ['./1210/1210.8363/7lane_formation_start-eps-converted-to.pdf', './1210/1210.8363/6transient_block3-eps-converted-to.pdf', './1210/1210.8363/3merge-eps-converted-to.pdf', './1210/1210.8363/w11-eps-converted-to.pdf', './1210/1210.8363/jam-eps-converted-to.pdf', './1210/1210.8363/w13-eps-converted-to.pdf', './1210/1210.8363/BM_nstudyN=1-eps-converted-to.pdf', './1210/1210.8363/q-eps-converted-to.pdf', './1210/1210.8363/2encounter-eps-converted-to.pdf', './1210/1210.7562/fig2.eps', './1210/1210.8363/blockphase-eps-converted-to.pdf', './1210/1210.8363/simu07-eps-converted-to.pdf', './1210/1210.8363/simu10-eps-converted-to.pdf', './1210/1210.8363/clogging-eps-converted-to.pdf', './1210/1210.8363/8lane-eps-converted-to.pdf', './1210/1210.8363/4transient_block-eps-converted-to.pdf', './1210/1210.7562/fig1b.eps', './1210/1210.8363/1initial-eps-converted-to.pdf', './1210/1210.8363/w12-eps-converted-to.pdf', './1210/1210.8363/schematic-eps-converted-to.pdf', './1210/1210.8363/9normal-eps-converted-to.pdf', './1210/1210.8363/N-eps-converted-to.pdf', './1210/1210.7562/fig1a.eps', './1210/1210.8363/5transient_block2-eps-converted-to.pdf']

# %%
print(ids)
# Out:
# [9059685, 9059696, 9059692, 9059687, 9059690, 9059698, 9059689, 9059699, 9059702, 9082443, 9059691, 9059686, 9059697, 9059700, 9059693, 9059684, 9082441, 9059694, 9059688, 9059695, 9059703, 9059704, 9082442, 9059701]

# %% [markdown]
# ### Used for generating figures for paper

# %%
# get a montage of some images

# print the current working directory
os.chdir('/home/rte/re-imaging/sqlite-scripts/')
print(os.getcwd())

os.chdir('/home/rte/arXiv/')
print(os.getcwd())

prearg = shlex.split("-colorspace CMYK")
# arguments = shlex.split("-colorspace sRGB -background white -alpha background -trim +repage -flatten -geometry 240x240+2+2 -tile 12x /home/rte/documentation/data-samples/test_py_montage.jpg")

# for bigger montage of 12x12
arguments = shlex.split("-colorspace sRGB -background white -alpha background -geometry 240x240+2+2 -tile 12x")
# for smaller montage of 4x4
# arguments = shlex.split("-colorspace sRGB -background white -alpha background -geometry 480x480+2+2 -tile 4x")

# outputname = ["/home/rte/documentation/data-samples/random_montage_12x12_stat.ML.jpg"]
outputname = ["/home/rte/documentation/data-samples/random_montage_nlin.CG.jpg"]
# print(arguments)

filelist = []
# this takes a slice of the larger shuffled list
for filepath in itertools.islice(filepaths, 0, 144):
#     print(filepath)
    # put the filepath into the list but add the directory, remove the dot
    # and also add [0] to only use the first page of multi-page image documents
    filelist.append("src_all" + filepath.replace('./','/') + '[0]')
           
# print(filelist)

# call the montage command and parse list of files and arguments
montage_cmd = ["montage"] + prearg + filelist + arguments + outputname

result = subprocess.Popen(montage_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
out, err = result.communicate()
print(out)
print(err)
print("subprocess finished")
print("-" * 40)
# Out:
# /home/rte/re-imaging/sqlite-scripts
# /mnt/hd-4tb/arXiv
# b''
# b''
# subprocess finished
# ----------------------------------------

# %%
# use this to copy to other files, paste as variable
print(ids)

# %%
# testing writing filenames

# os.chdir("/home/rte/re-imaging/sqlite-scripts/")
os.chdir("/home/rte/documentation/data-samples/")
print(os.getcwd())

# fname = "2018-10_" + catlist[0][0] + "_ids.txt"
fname = "random_montage_4x4_v2_ids.txt"
f = open(fname, "w+")
for row in ids:
    f.write(str(row) + "\n")
f.close()

# %%
for cat in catlist:
    print(cat[0])

# %%
print(len(filelist))

for row in filelist:
    print(row)

# %%
# testing writing filenames

fname = "2018-10_" + catlist[0][0] + ".txt"
f = open(fname, "w+")
for row in filelist:
    f.write(row + "\n")
f.close()

# %%
print(targetDate[:7])

# %%
targetYM = targetDate[:7]
savepath = "/home/rte/Documents/documentation/data-samples/montages/category/" + targetYM + "/"

if os.path.isdir(savepath):
    print("directory exists, saving to: " + savepath)
else:
    try:
        os.makedirs(savepath)
    except OSError:
        print("failed to create directory: " + savepath)
    else:
        print("successfully created the directory: " + savepath)

# %%
print(len(catlist))

for row in catlist:
    print(row[0])

# %% [markdown]
# The following block of code takes the list of categories, queries the SQL database for a list of images that match each category and a given year, then shuffles this list, selects a subset, and uses that to run the montage command ^_^

# %%
# added date formatting
sql = ('''
    SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created
    FROM images
    LEFT JOIN metadata ON images.identifier = metadata.identifier
    WHERE metadata.created BETWEEN date(?) AND date(?, 'start of month','+1 month','-1 day')
    AND images.x != ''
    AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ?
    ''')

targetYM = targetDate[:7]
savepath = "/home/rte/Documents/documentation/data-samples/montages/category/" + targetYM + "/"

if os.path.isdir(savepath):
    print("saving to: " + savepath)
else:
    try:
        os.makedirs(path)
    except OSError:
        print("Failed to create directory: " + savepath)
    else:
        print("Successfully created the directory: " + savepath)
        

for cat in catlist:
    print("querying for category: " + str(cat[0]))
    c.execute(sql, (targetDate, targetDate, cat[0], ))
    rows = c.fetchall()
    
    print("total number of images found: " + str(len(rows)))
    
    filepaths = []

    for row in rows:
        path = row[1] + '/' + row[2]
    #     print(path)
        filepaths.append(path)

    # shuffle the whole list
    random.shuffle(filepaths)
    
    os.chdir('/home/rte/re-imaging/sqlite-scripts/')

    # os.chdir('src_all')
#     print(os.getcwd())

    # format the arguments for montage
    arguments = shlex.split("-colorspace sRGB -units PixelsPerInch -density 300 -background white -alpha off -geometry 240x240+2+2 -tile 12x")

    filelist = []
    # this takes a slice of the larger shuffled list
    for filepath in itertools.islice(filepaths, 0, 144):
        # put the filepath into the list but add the directory, remove the dot
        # and also add [0] to only use the first page of multi-page image documents
        filelist.append("src_all" + filepath.replace('./','/') + '[0]')

    # write list of images to file (for debugging purposes, mostly)
    fname = savepath + targetYM + "_" + cat[0] + "_" + str(cat[1]) + ".txt"
    f = open(fname, "w+")
    for row in filelist:
        f.write(row + "\n")
    f.close()
    
#     outputname = "test_py_montage.jpg"
    outputname = [savepath + "montage_" + targetYM + "_" + cat[0] + "_" + str(cat[1]) + ".jpg"]

    print("calling montage")
    # call the montage command and parse list of files and arguments
    montage_cmd = ["montage"] + filelist + arguments + outputname
#     print(montage_cmd)
    result = subprocess.Popen(montage_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    out, err = result.communicate()
    print(out)
    print(err)
    print("subprocess finished")
    print("-" * 40)

# %% [markdown]
# ### Getting image montages for paper

# %%
# Get 144 images from nlin.CG from October 2012

targetDate = "2012-01-01"
endDate = "2012-12-31"

# sql = ("SELECT metadata.cat, images.path, images.filename, images.identifier, metadata.created, images.id "
#     "FROM images "
#     "LEFT JOIN metadata ON images.identifier = metadata.identifier "
#     "WHERE images.x != '' "
#     "AND metadata.created BETWEEN date('2012-10-01') "
#     "AND date('2012-10-31') "
#     "AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ? "
#     "AND images.id IN (SELECT images.id FROM images ORDER BY RANDOM() LIMIT 144) ")

# c.execute(sql, ("nlin.CG", ))
# rows = c.fetchall()

sql = '''
    SELECT '/mnt/hd2/images/all/' || images.id || '.jpg'
    FROM images
    LEFT JOIN metadata ON images.identifier = metadata.identifier
    WHERE metadata.created BETWEEN date(?) 
    AND date(?)
    AND images.x != ''
    AND substr(trim(metadata.cat),1,instr(trim(metadata.cat)||' ',' ')-1) = ?
    '''
c.execute(sql, (targetDate, endDate, "nlin.CG"))
rows = c.fetchall()
print(len(rows))
for row in rows:
    print(row)
# Out:
# ('/mnt/hd2/images/all/9082441.jpg',)
# ('/mnt/hd2/images/all/9082443.jpg',)
# ('/mnt/hd2/images/all/9082442.jpg',)
# ('/mnt/hd2/images/all/9059699.jpg',)
# ('/mnt/hd2/images/all/9059695.jpg',)
# ('/mnt/hd2/images/all/9059687.jpg',)
# ('/mnt/hd2/images/all/9059698.jpg',)
# ('/mnt/hd2/images/all/9059690.jpg',)
# ('/mnt/hd2/images/all/9059688.jpg',)
# ('/mnt/hd2/images/all/9059696.jpg',)
# ('/mnt/hd2/images/all/9059693.jpg',)
# ('/mnt/hd2/images/all/9059703.jpg',)
# ('/mnt/hd2/images/all/9059685.jpg',)
# ('/mnt/hd2/images/all/9059684.jpg',)
# ('/mnt/hd2/images/all/9059692.jpg',)
# ('/mnt/hd2/images/all/9059701.jpg',)
# ('/mnt/hd2/images/all/9059702.jpg',)
# ('/mnt/hd2/images/all/9059694.jpg',)
# ('/mnt/hd2/images/all/9059686.jpg',)
# ('/mnt/hd2/images/all/9059689.jpg',)
# ('/mnt/hd2/images/all/9059691.jpg',)
# ('/mnt/hd2/images/all/9059697.jpg',)
# ('/mnt/hd2/images/all/9059700.jpg',)
# ('/mnt/hd2/images/all/9059704.jpg',)
# ('/mnt/hd2/images/all/1050795.jpg',)
# ('/mnt/hd2/images/all/1050787.jpg',)
# ('/mnt/hd2/images/all/1050796.jpg',)
# ('/mnt/hd2/images/all/1050792.jpg',)
# ('/mnt/hd2/images/all/1050788.jpg',)
# ('/mnt/hd2/images/all/1050790.jpg',)
# ('/mnt/hd2/images/all/1050791.jpg',)
# ('/mnt/hd2/images/all/1050794.jpg',)
# ('/mnt/hd2/images/all/1050789.jpg',)
# ('/mnt/hd2/images/all/1050784.jpg',)
# ('/mnt/hd2/images/all/1050785.jpg',)
# ('/mnt/hd2/images/all/1050793.jpg',)
# ('/mnt/hd2/images/all/1050786.jpg',)
# ('/mnt/hd2/images/all/7939502.jpg',)
# ('/mnt/hd2/images/all/7939504.jpg',)
# ('/mnt/hd2/images/all/7939500.jpg',)
# ('/mnt/hd2/images/all/7939503.jpg',)
# ('/mnt/hd2/images/all/7939501.jpg',)
# ('/mnt/hd2/images/all/4271053.jpg',)
# ('/mnt/hd2/images/all/4271056.jpg',)
# ('/mnt/hd2/images/all/4271060.jpg',)
# ('/mnt/hd2/images/all/4271064.jpg',)
# ('/mnt/hd2/images/all/4271066.jpg',)
# ('/mnt/hd2/images/all/4271068.jpg',)
# ('/mnt/hd2/images/all/4271069.jpg',)
# ('/mnt/hd2/images/all/4271071.jpg',)
# ('/mnt/hd2/images/all/4271073.jpg',)
# ('/mnt/hd2/images/all/4271076.jpg',)
# ('/mnt/hd2/images/all/4271077.jpg',)
# ('/mnt/hd2/images/all/4271080.jpg',)
# ('/mnt/hd2/images/all/4271083.jpg',)
# ('/mnt/hd2/images/all/4271088.jpg',)
# ('/mnt/hd2/images/all/4271090.jpg',)
# ('/mnt/hd2/images/all/4271054.jpg',)
# ('/mnt/hd2/images/all/4271061.jpg',)
# ('/mnt/hd2/images/all/4271072.jpg',)
# ('/mnt/hd2/images/all/4271078.jpg',)
# ('/mnt/hd2/images/all/4271081.jpg',)
# ('/mnt/hd2/images/all/4271085.jpg',)
# ('/mnt/hd2/images/all/4271095.jpg',)
# ('/mnt/hd2/images/all/4271082.jpg',)
# ('/mnt/hd2/images/all/4271058.jpg',)
# ('/mnt/hd2/images/all/4271055.jpg',)
# ('/mnt/hd2/images/all/4271059.jpg',)
# ('/mnt/hd2/images/all/4271067.jpg',)
# ('/mnt/hd2/images/all/4271074.jpg',)
# ('/mnt/hd2/images/all/4271084.jpg',)
# ('/mnt/hd2/images/all/4271087.jpg',)
# ('/mnt/hd2/images/all/4271089.jpg',)
# ('/mnt/hd2/images/all/4271091.jpg',)
# ('/mnt/hd2/images/all/4271092.jpg',)
# ('/mnt/hd2/images/all/4271093.jpg',)
# ('/mnt/hd2/images/all/4271094.jpg',)
# ('/mnt/hd2/images/all/4271079.jpg',)
# ('/mnt/hd2/images/all/4271075.jpg',)
# ('/mnt/hd2/images/all/4271057.jpg',)
# ('/mnt/hd2/images/all/4271062.jpg',)
# ('/mnt/hd2/images/all/4271086.jpg',)
# ('/mnt/hd2/images/all/4271070.jpg',)
# ('/mnt/hd2/images/all/4271063.jpg',)
# ('/mnt/hd2/images/all/4271065.jpg',)
# ('/mnt/hd2/images/all/1055466.jpg',)
# ('/mnt/hd2/images/all/1055441.jpg',)
# ('/mnt/hd2/images/all/1055442.jpg',)
# ('/mnt/hd2/images/all/1055445.jpg',)
# ('/mnt/hd2/images/all/1055446.jpg',)
# ('/mnt/hd2/images/all/1055450.jpg',)
# ('/mnt/hd2/images/all/1055464.jpg',)
# ('/mnt/hd2/images/all/1055451.jpg',)
# ('/mnt/hd2/images/all/1055467.jpg',)
# ('/mnt/hd2/images/all/1055434.jpg',)
# ('/mnt/hd2/images/all/1055436.jpg',)
# ('/mnt/hd2/images/all/1055437.jpg',)
# ('/mnt/hd2/images/all/1055439.jpg',)
# ('/mnt/hd2/images/all/1055440.jpg',)
# ('/mnt/hd2/images/all/1055443.jpg',)
# ('/mnt/hd2/images/all/1055444.jpg',)
# ('/mnt/hd2/images/all/1055448.jpg',)
# ('/mnt/hd2/images/all/1055452.jpg',)
# ('/mnt/hd2/images/all/1055457.jpg',)
# ('/mnt/hd2/images/all/1055458.jpg',)
# ('/mnt/hd2/images/all/1055459.jpg',)
# ('/mnt/hd2/images/all/1055461.jpg',)
# ('/mnt/hd2/images/all/1055462.jpg',)
# ('/mnt/hd2/images/all/1055465.jpg',)
# ('/mnt/hd2/images/all/1055469.jpg',)
# ('/mnt/hd2/images/all/1055449.jpg',)
# ('/mnt/hd2/images/all/1055454.jpg',)
# ('/mnt/hd2/images/all/1055460.jpg',)
# ('/mnt/hd2/images/all/1055468.jpg',)
# ('/mnt/hd2/images/all/1055463.jpg',)
# ('/mnt/hd2/images/all/1055432.jpg',)
# ('/mnt/hd2/images/all/1055438.jpg',)
# ('/mnt/hd2/images/all/1055455.jpg',)
# ('/mnt/hd2/images/all/1055433.jpg',)
# ('/mnt/hd2/images/all/1055435.jpg',)
# ('/mnt/hd2/images/all/1055447.jpg',)
# ('/mnt/hd2/images/all/1055453.jpg',)
# ('/mnt/hd2/images/all/1055456.jpg',)
# ('/mnt/hd2/images/all/4400318.jpg',)
# ('/mnt/hd2/images/all/4400319.jpg',)
# ('/mnt/hd2/images/all/4400320.jpg',)
# ('/mnt/hd2/images/all/4400321.jpg',)
# ('/mnt/hd2/images/all/4400322.jpg',)
# ('/mnt/hd2/images/all/4400323.jpg',)
# ('/mnt/hd2/images/all/6647733.jpg',)
# ('/mnt/hd2/images/all/6647738.jpg',)
# ('/mnt/hd2/images/all/6647743.jpg',)
# ('/mnt/hd2/images/all/6647736.jpg',)
# ('/mnt/hd2/images/all/6647737.jpg',)
# ('/mnt/hd2/images/all/6647750.jpg',)
# ('/mnt/hd2/images/all/6647751.jpg',)
# ('/mnt/hd2/images/all/6647753.jpg',)
# ('/mnt/hd2/images/all/6647735.jpg',)
# ('/mnt/hd2/images/all/6647740.jpg',)
# ('/mnt/hd2/images/all/6647745.jpg',)
# ('/mnt/hd2/images/all/6647732.jpg',)
# ('/mnt/hd2/images/all/6647749.jpg',)
# ('/mnt/hd2/images/all/6647748.jpg',)
# ('/mnt/hd2/images/all/6647734.jpg',)
# ('/mnt/hd2/images/all/6647741.jpg',)
# ('/mnt/hd2/images/all/6647739.jpg',)
# ('/mnt/hd2/images/all/6647746.jpg',)
# ('/mnt/hd2/images/all/6647747.jpg',)
# ('/mnt/hd2/images/all/6647752.jpg',)
# ('/mnt/hd2/images/all/6647742.jpg',)
# ('/mnt/hd2/images/all/6647744.jpg',)
# ('/mnt/hd2/images/all/4421557.jpg',)
# ('/mnt/hd2/images/all/4421560.jpg',)
# ('/mnt/hd2/images/all/4421561.jpg',)
# ('/mnt/hd2/images/all/4421562.jpg',)
# ('/mnt/hd2/images/all/4421566.jpg',)
# ('/mnt/hd2/images/all/4421568.jpg',)
# ('/mnt/hd2/images/all/4421570.jpg',)
# ('/mnt/hd2/images/all/4421571.jpg',)
# ('/mnt/hd2/images/all/4421572.jpg',)
# ('/mnt/hd2/images/all/4421575.jpg',)
# ('/mnt/hd2/images/all/4421578.jpg',)
# ('/mnt/hd2/images/all/4421581.jpg',)
# ('/mnt/hd2/images/all/4421582.jpg',)
# ('/mnt/hd2/images/all/4421583.jpg',)
# ('/mnt/hd2/images/all/4421587.jpg',)
# ('/mnt/hd2/images/all/4421589.jpg',)
# ('/mnt/hd2/images/all/4421591.jpg',)
# ('/mnt/hd2/images/all/4421592.jpg',)
# ('/mnt/hd2/images/all/4421593.jpg',)
# ('/mnt/hd2/images/all/4421596.jpg',)
# ('/mnt/hd2/images/all/4421567.jpg',)
# ('/mnt/hd2/images/all/4421588.jpg',)
# ('/mnt/hd2/images/all/4421574.jpg',)
# ('/mnt/hd2/images/all/4421595.jpg',)
# ('/mnt/hd2/images/all/4421555.jpg',)
# ('/mnt/hd2/images/all/4421576.jpg',)
# ('/mnt/hd2/images/all/4421569.jpg',)
# ('/mnt/hd2/images/all/4421590.jpg',)
# ('/mnt/hd2/images/all/4421563.jpg',)
# ('/mnt/hd2/images/all/4421584.jpg',)
# ('/mnt/hd2/images/all/4421558.jpg',)
# ('/mnt/hd2/images/all/4421579.jpg',)
# ('/mnt/hd2/images/all/4421573.jpg',)
# ('/mnt/hd2/images/all/4421594.jpg',)
# ('/mnt/hd2/images/all/4421559.jpg',)
# ('/mnt/hd2/images/all/4421580.jpg',)
# ('/mnt/hd2/images/all/4421564.jpg',)
# ('/mnt/hd2/images/all/4421585.jpg',)
# ('/mnt/hd2/images/all/4421565.jpg',)
# ('/mnt/hd2/images/all/4421586.jpg',)
# ('/mnt/hd2/images/all/4421556.jpg',)
# ('/mnt/hd2/images/all/4421577.jpg',)
# ('/mnt/hd2/images/all/6633295.jpg',)
# ('/mnt/hd2/images/all/6633296.jpg',)
# ('/mnt/hd2/images/all/6633298.jpg',)
# ('/mnt/hd2/images/all/6633291.jpg',)
# ('/mnt/hd2/images/all/6633287.jpg',)
# ('/mnt/hd2/images/all/6633288.jpg',)
# ('/mnt/hd2/images/all/6633289.jpg',)
# ('/mnt/hd2/images/all/6633294.jpg',)
# ('/mnt/hd2/images/all/6633290.jpg',)
# ('/mnt/hd2/images/all/6633292.jpg',)
# ('/mnt/hd2/images/all/6633299.jpg',)
# ('/mnt/hd2/images/all/6633293.jpg',)
# ('/mnt/hd2/images/all/6633297.jpg',)
# ('/mnt/hd2/images/all/1110797.jpg',)
# ('/mnt/hd2/images/all/1110795.jpg',)
# ('/mnt/hd2/images/all/1110796.jpg',)
# ('/mnt/hd2/images/all/1110799.jpg',)
# ('/mnt/hd2/images/all/1110794.jpg',)
# ('/mnt/hd2/images/all/1110801.jpg',)
# ('/mnt/hd2/images/all/1110798.jpg',)
# ('/mnt/hd2/images/all/1110802.jpg',)
# ('/mnt/hd2/images/all/1110803.jpg',)
# ('/mnt/hd2/images/all/1110800.jpg',)
# ('/mnt/hd2/images/all/4254905.jpg',)
# ('/mnt/hd2/images/all/4254907.jpg',)
# ('/mnt/hd2/images/all/4254904.jpg',)
# ('/mnt/hd2/images/all/4254906.jpg',)
# ('/mnt/hd2/images/all/4254909.jpg',)
# ('/mnt/hd2/images/all/4254910.jpg',)
# ('/mnt/hd2/images/all/4254911.jpg',)
# ('/mnt/hd2/images/all/4254912.jpg',)
# ('/mnt/hd2/images/all/4254913.jpg',)
# ('/mnt/hd2/images/all/4254914.jpg',)
# ('/mnt/hd2/images/all/4254915.jpg',)
# ('/mnt/hd2/images/all/4254916.jpg',)
# ('/mnt/hd2/images/all/4254917.jpg',)
# ('/mnt/hd2/images/all/4254908.jpg',)
# ('/mnt/hd2/images/all/2682297.jpg',)
# ('/mnt/hd2/images/all/2682296.jpg',)
# ('/mnt/hd2/images/all/2682298.jpg',)
# ('/mnt/hd2/images/all/2646347.jpg',)
# ('/mnt/hd2/images/all/2646348.jpg',)
# ('/mnt/hd2/images/all/2646349.jpg',)
# ('/mnt/hd2/images/all/2646350.jpg',)
# ('/mnt/hd2/images/all/2646351.jpg',)
# ('/mnt/hd2/images/all/2646352.jpg',)
# ('/mnt/hd2/images/all/2646353.jpg',)
# ('/mnt/hd2/images/all/2646354.jpg',)
# ('/mnt/hd2/images/all/2646355.jpg',)
# ('/mnt/hd2/images/all/2646356.jpg',)
# ('/mnt/hd2/images/all/2646357.jpg',)
# ('/mnt/hd2/images/all/2646358.jpg',)
# ('/mnt/hd2/images/all/2646359.jpg',)
# ('/mnt/hd2/images/all/2646360.jpg',)
# ('/mnt/hd2/images/all/2646361.jpg',)
# ('/mnt/hd2/images/all/2646362.jpg',)
# ('/mnt/hd2/images/all/2646363.jpg',)
# ('/mnt/hd2/images/all/2646364.jpg',)
# ('/mnt/hd2/images/all/2646365.jpg',)
# ('/mnt/hd2/images/all/2646366.jpg',)
# ('/mnt/hd2/images/all/2646367.jpg',)
# ('/mnt/hd2/images/all/2666564.jpg',)
# ('/mnt/hd2/images/all/2666553.jpg',)
# ('/mnt/hd2/images/all/2666562.jpg',)
# ('/mnt/hd2/images/all/2666561.jpg',)
# ('/mnt/hd2/images/all/2666557.jpg',)
# ('/mnt/hd2/images/all/2666556.jpg',)
# ('/mnt/hd2/images/all/2666560.jpg',)
# ('/mnt/hd2/images/all/2666552.jpg',)
# ('/mnt/hd2/images/all/2666554.jpg',)
# ('/mnt/hd2/images/all/2666563.jpg',)
# ('/mnt/hd2/images/all/2666559.jpg',)
# ('/mnt/hd2/images/all/2666558.jpg',)
# ('/mnt/hd2/images/all/2666555.jpg',)
# ('/mnt/hd2/images/all/4257903.jpg',)
# ('/mnt/hd2/images/all/4257904.jpg',)
# ('/mnt/hd2/images/all/4257905.jpg',)
# ('/mnt/hd2/images/all/4257906.jpg',)
# ('/mnt/hd2/images/all/4257907.jpg',)
# ('/mnt/hd2/images/all/4257908.jpg',)
# ('/mnt/hd2/images/all/4257909.jpg',)
# ('/mnt/hd2/images/all/4257910.jpg',)
# ('/mnt/hd2/images/all/4257911.jpg',)
# ('/mnt/hd2/images/all/4257902.jpg',)
# ('/mnt/hd2/images/all/4257900.jpg',)
# ('/mnt/hd2/images/all/4257901.jpg',)
# ('/mnt/hd2/images/all/4257912.jpg',)
# ('/mnt/hd2/images/all/1057891.jpg',)
# ('/mnt/hd2/images/all/1057937.jpg',)
# ('/mnt/hd2/images/all/1057923.jpg',)
# ('/mnt/hd2/images/all/1057906.jpg',)
# ('/mnt/hd2/images/all/1057913.jpg',)
# ('/mnt/hd2/images/all/1057924.jpg',)
# ('/mnt/hd2/images/all/1057942.jpg',)
# ('/mnt/hd2/images/all/1057910.jpg',)
# ('/mnt/hd2/images/all/1057927.jpg',)
# ('/mnt/hd2/images/all/1057939.jpg',)
# ('/mnt/hd2/images/all/1057897.jpg',)
# ('/mnt/hd2/images/all/1057935.jpg',)
# ('/mnt/hd2/images/all/1057925.jpg',)
# ('/mnt/hd2/images/all/1057926.jpg',)
# ('/mnt/hd2/images/all/1057928.jpg',)
# ('/mnt/hd2/images/all/1057930.jpg',)
# ('/mnt/hd2/images/all/1057941.jpg',)
# ('/mnt/hd2/images/all/1057940.jpg',)
# ('/mnt/hd2/images/all/1057883.jpg',)
# ('/mnt/hd2/images/all/1057886.jpg',)
# ('/mnt/hd2/images/all/1057887.jpg',)
# ('/mnt/hd2/images/all/1057889.jpg',)
# ('/mnt/hd2/images/all/1057895.jpg',)
# ('/mnt/hd2/images/all/1057899.jpg',)
# ('/mnt/hd2/images/all/1057902.jpg',)
# ('/mnt/hd2/images/all/1057908.jpg',)
# ('/mnt/hd2/images/all/1057911.jpg',)
# ('/mnt/hd2/images/all/1057912.jpg',)
# ('/mnt/hd2/images/all/1057921.jpg',)
# ('/mnt/hd2/images/all/1057922.jpg',)
# ('/mnt/hd2/images/all/1057934.jpg',)
# ('/mnt/hd2/images/all/1057938.jpg',)
# ('/mnt/hd2/images/all/1057920.jpg',)
# ('/mnt/hd2/images/all/1057896.jpg',)
# ('/mnt/hd2/images/all/1057882.jpg',)
# ('/mnt/hd2/images/all/1057885.jpg',)
# ('/mnt/hd2/images/all/1057888.jpg',)
# ('/mnt/hd2/images/all/1057890.jpg',)
# ('/mnt/hd2/images/all/1057892.jpg',)
# ('/mnt/hd2/images/all/1057894.jpg',)
# ('/mnt/hd2/images/all/1057901.jpg',)
# ('/mnt/hd2/images/all/1057904.jpg',)
# ('/mnt/hd2/images/all/1057905.jpg',)
# ('/mnt/hd2/images/all/1057907.jpg',)
# ('/mnt/hd2/images/all/1057909.jpg',)
# ('/mnt/hd2/images/all/1057916.jpg',)
# ('/mnt/hd2/images/all/1057931.jpg',)
# ('/mnt/hd2/images/all/1057936.jpg',)
# ('/mnt/hd2/images/all/1057943.jpg',)
# ('/mnt/hd2/images/all/1057900.jpg',)
# ('/mnt/hd2/images/all/1057893.jpg',)
# ('/mnt/hd2/images/all/1057914.jpg',)
# ('/mnt/hd2/images/all/1057917.jpg',)
# ('/mnt/hd2/images/all/1057918.jpg',)
# ('/mnt/hd2/images/all/1057919.jpg',)
# ('/mnt/hd2/images/all/1057929.jpg',)
# ('/mnt/hd2/images/all/1057884.jpg',)
# ('/mnt/hd2/images/all/1057898.jpg',)
# ('/mnt/hd2/images/all/1057903.jpg',)
# ('/mnt/hd2/images/all/1057915.jpg',)
# ('/mnt/hd2/images/all/1057933.jpg',)
# ('/mnt/hd2/images/all/1057932.jpg',)
# ('/mnt/hd2/images/all/7556013.jpg',)
# ('/mnt/hd2/images/all/7556004.jpg',)
# ('/mnt/hd2/images/all/7556005.jpg',)
# ('/mnt/hd2/images/all/7556009.jpg',)
# ('/mnt/hd2/images/all/7556002.jpg',)
# ('/mnt/hd2/images/all/7556006.jpg',)
# ('/mnt/hd2/images/all/7556007.jpg',)
# ('/mnt/hd2/images/all/7556008.jpg',)
# ('/mnt/hd2/images/all/7556010.jpg',)
# ('/mnt/hd2/images/all/7556011.jpg',)
# ('/mnt/hd2/images/all/7556012.jpg',)
# ('/mnt/hd2/images/all/7556003.jpg',)
# ('/mnt/hd2/images/all/4263890.jpg',)
# ('/mnt/hd2/images/all/4263905.jpg',)
# ('/mnt/hd2/images/all/4263900.jpg',)
# ('/mnt/hd2/images/all/4263895.jpg',)
# ('/mnt/hd2/images/all/4263910.jpg',)
# ('/mnt/hd2/images/all/4263912.jpg',)
# ('/mnt/hd2/images/all/4263896.jpg',)
# ('/mnt/hd2/images/all/4263898.jpg',)
# ('/mnt/hd2/images/all/4263903.jpg',)
# ('/mnt/hd2/images/all/4263906.jpg',)
# ('/mnt/hd2/images/all/4263902.jpg',)
# ('/mnt/hd2/images/all/4263909.jpg',)
# ('/mnt/hd2/images/all/4263887.jpg',)
# ('/mnt/hd2/images/all/4263904.jpg',)
# ('/mnt/hd2/images/all/4263892.jpg',)
# ('/mnt/hd2/images/all/4263891.jpg',)
# ('/mnt/hd2/images/all/4263889.jpg',)
# ('/mnt/hd2/images/all/4263908.jpg',)
# ('/mnt/hd2/images/all/4263911.jpg',)
# ('/mnt/hd2/images/all/4263897.jpg',)
# ('/mnt/hd2/images/all/4263901.jpg',)
# ('/mnt/hd2/images/all/4263899.jpg',)
# ('/mnt/hd2/images/all/4263907.jpg',)
# ('/mnt/hd2/images/all/4263913.jpg',)
# ('/mnt/hd2/images/all/4263914.jpg',)
# ('/mnt/hd2/images/all/4263888.jpg',)
# ('/mnt/hd2/images/all/4263893.jpg',)
# ('/mnt/hd2/images/all/4263894.jpg',)
# ('/mnt/hd2/images/all/4015127.jpg',)
# ('/mnt/hd2/images/all/4015144.jpg',)
# ('/mnt/hd2/images/all/4015100.jpg',)
# ('/mnt/hd2/images/all/4015101.jpg',)
# ('/mnt/hd2/images/all/4015102.jpg',)
# ('/mnt/hd2/images/all/4015103.jpg',)
# ('/mnt/hd2/images/all/4015104.jpg',)
# ('/mnt/hd2/images/all/4015105.jpg',)
# ('/mnt/hd2/images/all/4015106.jpg',)
# ('/mnt/hd2/images/all/4015107.jpg',)
# ('/mnt/hd2/images/all/4015108.jpg',)
# ('/mnt/hd2/images/all/4015109.jpg',)
# ('/mnt/hd2/images/all/4015110.jpg',)
# ('/mnt/hd2/images/all/4015111.jpg',)
# ('/mnt/hd2/images/all/4015112.jpg',)
# ('/mnt/hd2/images/all/4015113.jpg',)
# ('/mnt/hd2/images/all/4015114.jpg',)
# ('/mnt/hd2/images/all/4015115.jpg',)
# ('/mnt/hd2/images/all/4015116.jpg',)
# ('/mnt/hd2/images/all/4015117.jpg',)
# ('/mnt/hd2/images/all/4015118.jpg',)
# ('/mnt/hd2/images/all/4015119.jpg',)
# ('/mnt/hd2/images/all/4015120.jpg',)
# ('/mnt/hd2/images/all/4015121.jpg',)
# ('/mnt/hd2/images/all/4015122.jpg',)
# ('/mnt/hd2/images/all/4015125.jpg',)
# ('/mnt/hd2/images/all/4015126.jpg',)
# ('/mnt/hd2/images/all/4015129.jpg',)
# ('/mnt/hd2/images/all/4015130.jpg',)
# ('/mnt/hd2/images/all/4015131.jpg',)
# ('/mnt/hd2/images/all/4015132.jpg',)
# ('/mnt/hd2/images/all/4015133.jpg',)
# ('/mnt/hd2/images/all/4015135.jpg',)
# ('/mnt/hd2/images/all/4015136.jpg',)
# ('/mnt/hd2/images/all/4015142.jpg',)
# ('/mnt/hd2/images/all/4015123.jpg',)
# ('/mnt/hd2/images/all/4015124.jpg',)
# ('/mnt/hd2/images/all/4015128.jpg',)
# ('/mnt/hd2/images/all/4015134.jpg',)
# ('/mnt/hd2/images/all/4015137.jpg',)
# ('/mnt/hd2/images/all/4015138.jpg',)
# ('/mnt/hd2/images/all/4015139.jpg',)
# ('/mnt/hd2/images/all/4015140.jpg',)
# ('/mnt/hd2/images/all/4015141.jpg',)
# ('/mnt/hd2/images/all/4015143.jpg',)
# ('/mnt/hd2/images/all/8110052.jpg',)
# ('/mnt/hd2/images/all/8110053.jpg',)
# ('/mnt/hd2/images/all/8110051.jpg',)
# ('/mnt/hd2/images/all/8110054.jpg',)
# ('/mnt/hd2/images/all/8110055.jpg',)

# %%
filepaths = []
for row in rows:
    filepaths.append(row[0])
# print(filepaths)

random.shuffle(filepaths)

# savepath = "/home/rte/documentation/dataset-methods-paper/montages/" + "nlin.CG_" + targetDate + ".jpg"
savepath = "/home/rte/documentation/dataset-methods-paper/montages/" + "nlin.CG_all2012"+ ".jpg"

print(savepath)
arguments = shlex.split("-colorspace sRGB -units PixelsPerInch -density 300 -background white -alpha off -geometry 240x240+2+2 -tile 12x")

filelist = []
# this takes a slice of the larger shuffled list
for filepath in itertools.islice(filepaths, 0, 144):
    # put the filepath into the list but add the directory, remove the dot
    # and also add [0] to only use the first page of multi-page image documents
    filelist.append(filepath.replace('./','/') + '[0]')
print(filelist)        
        
# # write list of images to file (for debugging purposes, mostly)
# fname = "nlin.CG_2012" + ".txt"
# with open(fname, "w+") as f:
#     for row in filelist:
#         f.write(row + "\n")
        
montage_cmd = ["montage"] + filelist + arguments + [savepath]

result = subprocess.Popen(montage_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
out, err = result.communicate()
print(out)
print(err)
print("subprocess finished")
print("-" * 40)
# Out:
# /home/rte/documentation/dataset-methods-paper/montages/nlin.CG_all2012.jpg
# ['/mnt/hd2/images/all/1057910.jpg[0]', '/mnt/hd2/images/all/4271058.jpg[0]', '/mnt/hd2/images/all/4421589.jpg[0]', '/mnt/hd2/images/all/4015104.jpg[0]', '/mnt/hd2/images/all/6647740.jpg[0]', '/mnt/hd2/images/all/6647748.jpg[0]', '/mnt/hd2/images/all/6647747.jpg[0]', '/mnt/hd2/images/all/4015137.jpg[0]', '/mnt/hd2/images/all/2646354.jpg[0]', '/mnt/hd2/images/all/9059700.jpg[0]', '/mnt/hd2/images/all/4271079.jpg[0]', '/mnt/hd2/images/all/2666562.jpg[0]', '/mnt/hd2/images/all/1050787.jpg[0]', '/mnt/hd2/images/all/1057902.jpg[0]', '/mnt/hd2/images/all/6633287.jpg[0]', '/mnt/hd2/images/all/2646352.jpg[0]', '/mnt/hd2/images/all/9059688.jpg[0]', '/mnt/hd2/images/all/1057905.jpg[0]', '/mnt/hd2/images/all/4263892.jpg[0]', '/mnt/hd2/images/all/1057889.jpg[0]', '/mnt/hd2/images/all/4015116.jpg[0]', '/mnt/hd2/images/all/4400318.jpg[0]', '/mnt/hd2/images/all/4271083.jpg[0]', '/mnt/hd2/images/all/4271064.jpg[0]', '/mnt/hd2/images/all/1110799.jpg[0]', '/mnt/hd2/images/all/4271090.jpg[0]', '/mnt/hd2/images/all/7939500.jpg[0]', '/mnt/hd2/images/all/4271077.jpg[0]', '/mnt/hd2/images/all/1110803.jpg[0]', '/mnt/hd2/images/all/9059686.jpg[0]', '/mnt/hd2/images/all/4015122.jpg[0]', '/mnt/hd2/images/all/9059703.jpg[0]', '/mnt/hd2/images/all/2646364.jpg[0]', '/mnt/hd2/images/all/6647753.jpg[0]', '/mnt/hd2/images/all/4015105.jpg[0]', '/mnt/hd2/images/all/1057917.jpg[0]', '/mnt/hd2/images/all/4263906.jpg[0]', '/mnt/hd2/images/all/1055438.jpg[0]', '/mnt/hd2/images/all/1050793.jpg[0]', '/mnt/hd2/images/all/1057897.jpg[0]', '/mnt/hd2/images/all/1057922.jpg[0]', '/mnt/hd2/images/all/2682297.jpg[0]', '/mnt/hd2/images/all/7556008.jpg[0]', '/mnt/hd2/images/all/4421583.jpg[0]', '/mnt/hd2/images/all/9059697.jpg[0]', '/mnt/hd2/images/all/4015123.jpg[0]', '/mnt/hd2/images/all/4257901.jpg[0]', '/mnt/hd2/images/all/2666555.jpg[0]', '/mnt/hd2/images/all/2682298.jpg[0]', '/mnt/hd2/images/all/2646367.jpg[0]', '/mnt/hd2/images/all/1055465.jpg[0]', '/mnt/hd2/images/all/6647733.jpg[0]', '/mnt/hd2/images/all/4421592.jpg[0]', '/mnt/hd2/images/all/7556011.jpg[0]', '/mnt/hd2/images/all/6647749.jpg[0]', '/mnt/hd2/images/all/4015102.jpg[0]', '/mnt/hd2/images/all/1057904.jpg[0]', '/mnt/hd2/images/all/4263911.jpg[0]', '/mnt/hd2/images/all/4015133.jpg[0]', '/mnt/hd2/images/all/7556007.jpg[0]', '/mnt/hd2/images/all/1057916.jpg[0]', '/mnt/hd2/images/all/6633299.jpg[0]', '/mnt/hd2/images/all/8110051.jpg[0]', '/mnt/hd2/images/all/1057926.jpg[0]', '/mnt/hd2/images/all/1055444.jpg[0]', '/mnt/hd2/images/all/1055453.jpg[0]', '/mnt/hd2/images/all/2646349.jpg[0]', '/mnt/hd2/images/all/1110802.jpg[0]', '/mnt/hd2/images/all/4015109.jpg[0]', '/mnt/hd2/images/all/1050791.jpg[0]', '/mnt/hd2/images/all/4263887.jpg[0]', '/mnt/hd2/images/all/4421593.jpg[0]', '/mnt/hd2/images/all/1057891.jpg[0]', '/mnt/hd2/images/all/6647750.jpg[0]', '/mnt/hd2/images/all/1057914.jpg[0]', '/mnt/hd2/images/all/4254913.jpg[0]', '/mnt/hd2/images/all/4400323.jpg[0]', '/mnt/hd2/images/all/1055447.jpg[0]', '/mnt/hd2/images/all/9059692.jpg[0]', '/mnt/hd2/images/all/6647736.jpg[0]', '/mnt/hd2/images/all/1057900.jpg[0]', '/mnt/hd2/images/all/1057892.jpg[0]', '/mnt/hd2/images/all/7556002.jpg[0]', '/mnt/hd2/images/all/4271095.jpg[0]', '/mnt/hd2/images/all/1055468.jpg[0]', '/mnt/hd2/images/all/1055463.jpg[0]', '/mnt/hd2/images/all/6647743.jpg[0]', '/mnt/hd2/images/all/4263913.jpg[0]', '/mnt/hd2/images/all/9059689.jpg[0]', '/mnt/hd2/images/all/4421576.jpg[0]', '/mnt/hd2/images/all/1055441.jpg[0]', '/mnt/hd2/images/all/4263908.jpg[0]', '/mnt/hd2/images/all/7556004.jpg[0]', '/mnt/hd2/images/all/4271060.jpg[0]', '/mnt/hd2/images/all/2646355.jpg[0]', '/mnt/hd2/images/all/1057898.jpg[0]', '/mnt/hd2/images/all/1055446.jpg[0]', '/mnt/hd2/images/all/1057939.jpg[0]', '/mnt/hd2/images/all/1050785.jpg[0]', '/mnt/hd2/images/all/4257903.jpg[0]', '/mnt/hd2/images/all/1057890.jpg[0]', '/mnt/hd2/images/all/1057907.jpg[0]', '/mnt/hd2/images/all/9059698.jpg[0]', '/mnt/hd2/images/all/4254907.jpg[0]', '/mnt/hd2/images/all/1110801.jpg[0]', '/mnt/hd2 ...
# b''
# b''
# subprocess finished
# ----------------------------------------
